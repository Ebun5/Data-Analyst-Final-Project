# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebun5/Final-ExcelProject/blob/main/Final_Project_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Dictionary**
#
# **ID:** Unique passenger identifier
#
# **Gender**: Gender of the passenger (Female/Male)
# **Age:** Age of the passenger
# **Customer Type:** Type of airline customer (First-time/Returning)
# **Type of Travel:** Purpose of the flight (Business/Personal)
# **Class:** Travel class in the airplane for the passenger seat
# **Flight Distance:** Flight distance in miles
# **Departure Delay:** Flight departure delay in minutes
# **Arrival Delay:** Flight arrival delay in minutes
# **Departure and Arrival Time Convenience:** Satisfaction level with the convenience of the flight departure and arrival times from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Ease of Online Booking:** Satisfaction level with the online booking experience from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Check-in Service:** Satisfaction level with the check-in service from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Online Boarding:** Satisfaction level with the online boarding experience from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Gate Location:** Satisfaction level with the gate location in the airport from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **On-board Service:** Satisfaction level with the on-boarding service in the airport from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Seat Comfort:** Satisfaction level with the comfort of the airplane seat from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Leg Room Service:** Satisfaction level with the leg room of the airplane seat from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# Cleanliness: Satisfaction level with the cleanliness of the airplane from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Food and Drink:** Satisfaction level with the food and drinks on the airplane from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **In-flight Service:** Satisfaction level with the in-flight service from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **In-flight Wifi Service:** Satisfaction level with the in-flight Wifi service from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **In-flight Entertainment:** Satisfaction level with the in-flight entertainment from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Baggage Handling:** Satisfaction level with the baggage handling from the airline from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# **Satisfaction:** Overall satisfaction level with the airline (Satisfied/Neutral or unsatisfied)
#
# **TASK: **
# To use the dataste to make some business analysis related to different level of satisfaction on services receive by Airline Passenger.

# %% [markdown]
# **Importing Libriaries and Reading Data**

# %% [markdown]
# For me to gain access to many functions for performing data analysis (for example, Modelling, Analyzing & Manipulation) it is essential to import Pandas as pd.
# i will also need to import Numpy as np in oder to facilitates efficient numerical operations on my large quantities od data (129881 rows x 24 column)

# %%
import numpy as np

import pandas as pd
df = pd.read_csv("/content/airline_passenger_satisfaction.csv")   #read the data
print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# **EXPLORING THE DATA**

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %% [markdown]
# To check the number of maximum returned rows

# %%
df.tail()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 129875                                       4  ...                 5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %% [markdown]
# The Arrival Delay has 393 null values.
# Deciding to drop the null values, it is important to find the % value compare to the whole data value.

# %%
df["Arrival Delay"].isnull().sum()/ df.shape[0]
# Out:
# 0.003025870033877425

# %%
x=df["Arrival Delay"].isnull().sum()/df.shape[0]

# %%
print(x)
# Out:
# 0.003025870033877425

# %%
print('{:,.2%}'.format(x))
# Out:
# 0.30%

# %% [markdown]
# Since the percentage of Null value is relatively small (0.39%), rather than dropping the Null value, i counted the unique number in the "Arrival Delay" column.

# %%
df["Arrival Delay"].value_counts()
# Out:
# 0.0       72753
# 1.0        2747
# 2.0        2587
# 3.0        2442
# 4.0        2373
#           ...
# 1011.0        1
# 386.0         1
# 624.0         1
# 355.0         1
# 412.0         1
# Name: Arrival Delay, Length: 472, dtype: int64

# %% [markdown]
# Since 0.0 is the most common value in the Arrival Delay column, I decided to replace all the Null value in the column with 0.0

# %%
df["Arrival delay"]=df["Arrival Delay"].fillna(0,inplace=True)

# %%
df["Arrival Delay"].value_counts()
# Out:
# 0.0       73146
# 1.0        2747
# 2.0        2587
# 3.0        2442
# 4.0        2373
#           ...
# 1011.0        1
# 386.0         1
# 624.0         1
# 355.0         1
# 412.0         1
# Name: Arrival Delay, Length: 472, dtype: int64

# %% [markdown]
# To ensure that the Dataset is more clean, I dropped the "ID Column" since it does not contribute to any pattens and relationship in the dataset to make decision

# %%
df.drop("ID",axis = 1, inplace =True)

# %%
df.sample(10)
# Out:
#         Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 14012   Female   45     Returning       Business   Economy              182
# 82399     Male   25    First-time       Business  Business              500
# 81534   Female   36     Returning       Business  Business             3499
# 97240     Male   50     Returning       Business  Business             3858
# 48003     Male   13    First-time       Business   Economy              550
# 107177  Female   38    First-time       Business   Economy              402
# 99132   Female   33     Returning       Personal   Economy              237
# 18207     Male   30     Returning       Business  Business              179
# 110530  Female   55     Returning       Business  Business             3074
# 54092   Female   50     Returning       Personal   Economy             1416
#
#         Departure Delay  Arrival Delay  \
# 14012                 0            0.0
# 82399                 0            0.0
# ...

# %% [markdown]
# It is time to visualize the clean data by importing the right libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x="Type of Travel",data=df)
# Out:
# <Axes: xlabel='Type of Travel', ylabel='count'>

# %% [markdown]
# The above plot shows that the number count of 'Business' type of travel is more than 'Personal' type of travel.

# %% [markdown]
# Next, is to find if Passengers 'Type of Travel' relate to their 'Class' of travel.

# %%
sns.countplot(x="Class",data=df, hue="Type of Travel")
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# The above plot shows that 'Business' type of travel passengers travel more in business Class than Economy Class likewise 'Personal' type of travel passengers travel more in Economy Class.

# %% [markdown]
# Let us check the proportion of Class of travel

# %%
plt.figure(figsize=[6,6])
explode = [0,0,0.10]
labels=df['Class'].value_counts().index
values= df['Class'].value_counts().values
plt.pie(x= values, labels = labels, autopct='%0.4g%%', wedgeprops=
  {'edgecolor': 'black'},textprops = {'fontsize': 12}, shadow=True, explode = explode)
plt.show()

# %%
sns.countplot(x="Class", data=df, hue="Food and Drink")
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# The passengers in 'Business' Class are more satisfied with 'Food and Drink' service compared to passengers in 'Economy' Class followed by passengers in 'Economy Plus' Class. Proportionately, less than 6000 passengers in 'Business' Class rated Food and Drink = '1' compared to up to 10000 passengers in 'Economy' Class rating Food and Drink ='1'

# %%
sns.countplot(x="Class", data=df, hue= "Customer Type")
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Age", data=df, hue="Ease of Online Booking")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.lineplot(x='Age', y='Ease of Online Booking', data=df, hue= 'Satisfaction')
# Out:
# <Axes: xlabel='Age', ylabel='Ease of Online Booking'>

# %%
sns.countplot(x= "On-board Service", data=df, hue= "Class")
# Out:
# <Axes: xlabel='On-board Service', ylabel='count'>

# %% [markdown]
# The 'Business' Class is most satisfied on all Onboard services. This implies value for the 'ticket price' paid.

# %%
sns.countplot(x='Departure and Arrival Time Convenience',data=df, hue='Type of Travel')
# Out:
# <Axes: xlabel='Departure and Arrival Time Convenience', ylabel='count'>

# %%
sns.histplot(x='Age', data=df, hue='Satisfaction')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.barplot(x='Class', y='Leg Room Service', data= df, hue='Satisfaction')
# Out:
# <Axes: xlabel='Class', ylabel='Leg Room Service'>

# %%
sns.barplot(x='Class', y='Seat Comfort', data=df, hue='Satisfaction')
# Out:
# <Axes: xlabel='Class', ylabel='Seat Comfort'>

# %%
sns.lineplot(x='Age', y='Gate Location', data=df, hue='Satisfaction')
# Out:
# <Axes: xlabel='Age', ylabel='Gate Location'>

# %%
sns.barplot(x='Gender', y='Baggage Handling', data=df, hue='Satisfaction')
# Out:
# <Axes: xlabel='Gender', ylabel='Baggage Handling'>

# %%
plt.figure(figsize= (14,8))
sns.heatmap(df.corr(), annot = True, cmap='PuBu')
# Out:
# <Axes: >

# %% [markdown]
# To find the relationship between Class of travel and Age of Airline passenger.

# %%
sns.violinplot(data=df, x= 'Age', y= 'Class', pallete = 'Magma')
# Out:
# <Axes: xlabel='Age', ylabel='Class'>

# %% [markdown]
# 'Age' between 40 and 60 is most related to 'Business'Class
# 'Age' in 20s are most related to 'Economy' Class
# 'Age' between 30 and 40 are most related to 'Economy plus' Class
